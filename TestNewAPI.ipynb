# %%
import json
import requests
import time
import pandas as pd
import csv
from datetime import datetime
import pandas as pd

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.76 Safari/537.36'} 
url="https://www.radarbox24.com/search/flights?destination=LFLL&minarrs=1594342799&maxarrs=1582848000&first=100&reverse=0"
response = requests.get(url, headers=headers)
data_arrive=response.json()
df_arrive = pd.DataFrame(data_arrive) 
variabletodrop=['replay','isFuture', 'departureRelative','statusLabel','arrivalRelative']
df_arrive.drop(variabletodrop,axis=1)
#ecrire dans un fichier CSV mon dataframe
#df_arrive.to_csv('arrive27.csv',index=False)
# Out:
#            fid                    acd     acr   act alic  \
# 0   1393486144         Boeing 737-300    None  B733  NPT
# 1   1394167007      Boeing 767-346ERF  OY-SRW  B763  SRR
# 2   1394170326       Boeing 757-28ASF  D-ALET  B752  BCS
# 3   1394129788  Airbus A300B4-622R(F)  D-AEAG  A306  BCS
# 4   1394268455        Airbus A319-111  F-GRHQ  A319  AFR
# ..         ...                    ...     ...   ...  ...
# 95  1394355417        Airbus A320-216  EC-MUF  A320  IBS
# 96  1394310754         Boeing 737-8K2  F-GZHQ  B738  TVF
# 97  1394348864      Embraer 190-100LR  CS-TPT  E190  TAP
# 98  1394355333        Airbus A320-214  D-AIZX  A320  DLH
# 99  1394357277        Airbus A320-214  F-HBNJ  A320  AFR
#
#                       alna    alt apdstci apdstco apdstia  ...     day  \
# 0         West Atlantic UK      0    Lyon  France     LYS  ...  27 Feb
# 1                 Star Air   2425    Lyon  France     LYS  ...  27 Feb
# ...

# %%
data_arrive[4]
# Out:
# {'fid': 1394268455,
#  'acd': 'Airbus A319-111',
#  'acr': 'F-GRHQ',
#  'act': 'A319',
#  'alic': 'AFR',
#  'alna': 'Air France',
#  'alt': 1150,
#  'apdstci': 'Lyon',
#  'apdstco': 'France',
#  'apdstia': 'LYS',
#  'apdstic': 'LFLL',
#  'apdstla': 45.7264,
#  'apdstlo': 5.09083,
#  'apdstst': 'Rhône Alpes',
#  'apdsttz': 1,
#  'apdsttznl': 'Central European Standard Time',
#  'apdsttzns': 'CET',
#  'aporgci': 'Toulouse',
#  'aporgco': 'France',
#  'aporgia': 'TLS',
#  'aporgic': 'LFBO',
#  'aporgla': 43.6291,
#  'aporglo': 1.36382,
#  'aporgst': 'Midi-Pyrénées',
#  'aporgtz': 1,
#  'aporgtznl': 'Central European Standard Time',
#  'aporgtzns': 'CET',
#  'arrau': 1582785180,
#  'arre': '07:35',
#  'arreu': 1582785300,
#  'arrs': '07:40',
#  'arrsu': 1582785600,
#  'cancel': None,
#  'cs': 'AFR1713',
#  'depau': 1582781700,
#  'depe': None,
#  'depeu': None,
#  'deps': '06:40',
#  'depsu': 1582782000,
#  'fnia': 'AF1713',
#  'fnic': 'AFR1713',
#  'lastlalot': 1582784956623,
# ...

# %%
df=df_arrive['arreu'],'arrau']]
# Out:
#   File "<ipython-input-134-a592d76cc939>", line 1
#     df=df_arrive['arreu'],'arrau']]
#                                  ^
# SyntaxError: invalid syntax

# %%
df=pd.read_csv('newapi.csv')

# %%
df_arrive
# Out:
#             fid                    acd     acr   act alic  \
# 0    1393132869         Boeing 737-300    None  B733  NPT
# 1    1393813411       Boeing 757-2Q8SF  D-ALEN  B752  BCS
# 2    1393814910  Airbus A300B4-622R(F)  D-AEAG  A306  BCS
# 3    1393821833        Boeing 737-4Q8F  OE-IAK  B734  TAY
# 4    1393831333        Airbus A319-111  F-GRHE  A319  AFR
# ..          ...                    ...     ...   ...  ...
# 132  1394052503        Boeing 737-4Q8F  OE-IAK  B734  TAY
# 133  1394060651        Airbus A320-214  G-EZGY  A320  EJU
# 134  1394086945        Airbus A320-214  D-AIUW  A320  DLH
# 135  1394090198        Airbus A321-212  F-GTAT  A321  AFR
# 136  1394056646        Airbus A320-214  OE-ICC  A320  EJU
#
#                        alna   alt apdstci apdstco apdstia  ...  \
# 0          West Atlantic UK     0    Lyon  France     LYS  ...
# 1    European Air Transport  1800    Lyon  France     LYS  ...
# 2    European Air Transport  2425    Lyon  France     LYS  ...
# ...

# %%
for d in data:
    print(d['statusLabel'])
# Out:
# {'text': 'LANDED 1d 11h AGO', 'bg': '#0e7677', 'label': '#FFFFFF'}
# {'text': 'LANDED', 'bg': '#0e7677', 'label': '#FFFFFF'}
# {'text': 'LANDED', 'bg': '#0e7677', 'label': '#FFFFFF'}
# {'text': 'LANDED 1d 7h AGO', 'bg': '#0e7677', 'label': '#FFFFFF'}
# {'text': 'LANDED 1d 6h AGO', 'bg': '#0e7677', 'label': '#FFFFFF'}
# {'text': 'LANDED 1d 6h AGO', 'bg': '#0e7677', 'label': '#FFFFFF'}
# {'text': 'LANDED 1d 6h AGO', 'bg': '#0e7677', 'label': '#FFFFFF'}
# {'text': 'LANDED 1d 6h AGO', 'bg': '#0e7677', 'label': '#FFFFFF'}
# {'text': 'LANDED 1d 6h AGO', 'bg': '#0e7677', 'label': '#FFFFFF'}
# {'text': 'LANDED 1d 6h AGO', 'bg': '#0e7677', 'label': '#FFFFFF'}
# {'text': 'LANDED 1d 6h AGO', 'bg': '#0e7677', 'label': '#FFFFFF'}
# {'text': 'LANDED 1d 6h AGO', 'bg': '#0e7677', 'label': '#FFFFFF'}
# {'text': 'LANDED 1d 5h AGO', 'bg': '#0e7677', 'label': '#FFFFFF'}
# {'text': 'LANDED 1d 6h AGO', 'bg': '#0e7677', 'label': '#FFFFFF'}
# {'text': 'CANCELLED', 'bg': '#6f807c', 'label': '#FFFFFF'}
# ...

# %%
df1
# Out:
#             fid                    acd     acr   act alic  \
# 0    1393132869         Boeing 737-300    None  B733  NPT
# 1    1393813411       Boeing 757-2Q8SF  D-ALEN  B752  BCS
# 2    1393814910  Airbus A300B4-622R(F)  D-AEAG  A306  BCS
# 3    1393821833        Boeing 737-4Q8F  OE-IAK  B734  TAY
# 4    1393831333        Airbus A319-111  F-GRHE  A319  AFR
# ..          ...                    ...     ...   ...  ...
# 132  1394052503        Boeing 737-4Q8F  OE-IAK  B734  TAY
# 133  1394060651        Airbus A320-214  G-EZGY  A320  EJU
# 134  1394086945        Airbus A320-214  D-AIUW  A320  DLH
# 135  1394090198        Airbus A321-212  F-GTAT  A321  AFR
# 136  1394056646        Airbus A320-214  OE-ICC  A320  EJU
#
#                        alna   alt apdstci apdstco apdstia  ...  \
# 0          West Atlantic UK     0    Lyon  France     LYS  ...
# 1    European Air Transport  1800    Lyon  France     LYS  ...
# 2    European Air Transport  2425    Lyon  France     LYS  ...
# ...

# %%
df.columns
# Out:
# Index(['fid', 'acd', 'acr', 'act', 'alic', 'alna', 'alt', 'apdstci', 'apdstco',
#        'apdstia', 'apdstic', 'apdstla', 'apdstlo', 'apdstst', 'apdsttz',
#        'apdsttznl', 'apdsttzns', 'aporgci', 'aporgco', 'aporgia', 'aporgic',
#        'aporgla', 'aporglo', 'aporgst', 'aporgtz', 'aporgtznl', 'aporgtzns',
#        'arrau', 'arre', 'arreu', 'arrs', 'arrsu', 'cancel', 'cs', 'depau',
#        'depe', 'depeu', 'deps', 'depsu', 'fnia', 'fnic', 'mrgarru', 'mrgdepu',
#        'so', 'svd', 'lastlalot', 'departure', 'departure_meta', 'arrival',
#        'arrival_meta', 'status', 'delay', 'progress', 'duration',
#        'durationType', 'distance', 'departureRelative', 'arrivalRelative',
#        'statusLabel', 'depsts', 'depc', 'arrsts', 'arrc', 'day', 'depdate',
#        'arrdate', 'replay', 'isFuture', 'pcnt', 'tkotc', 'lngtc', 'deptaxi',
#        'arrdelay', 'depdelay', 'arrtaxi'],
#       dtype='object')

# %%
df[df.day=='26 Feb']
# Out:
#             fid                    acd     acr   act alic  \
# 0    1393132869         Boeing 737-300    None  B733  NPT
# 1    1393813411       Boeing 757-2Q8SF  D-ALEN  B752  BCS
# 2    1393814910  Airbus A300B4-622R(F)  D-AEAG  A306  BCS
# 3    1393821833        Boeing 737-4Q8F  OE-IAK  B734  TAY
# 4    1393831333        Airbus A319-111  F-GRHE  A319  AFR
# ..          ...                    ...     ...   ...  ...
# 132  1394052503        Boeing 737-4Q8F  OE-IAK  B734  TAY
# 133  1394060651        Airbus A320-214  G-EZGY  A320  EJU
# 134  1394086945        Airbus A320-214  D-AIUW  A320  DLH
# 135  1394090198        Airbus A321-212  F-GTAT  A321  AFR
# 136  1394056646        Airbus A320-214  OE-ICC  A320  EJU
#
#                        alna   alt apdstci apdstco apdstia  ...  \
# 0          West Atlantic UK     0    Lyon  France     LYS  ...
# 1    European Air Transport  1800    Lyon  France     LYS  ...
# 2    European Air Transport  2425    Lyon  France     LYS  ...
# ...

# %%
df[['depsts','depc','arrsts','arrc']].isnull().sum()
# Out:
# depsts    0
# depc      0
# arrsts    0
# arrc      0
# dtype: int64

# %%
https://www.radarbox24.com/search/flights?origin=LFLL&minarrs=1582675200&maxarrs=1582761599&first=20&reverse=0

# %%
import json
import requests
import time
import pandas as pd
import csv
from datetime import datetime
import pandas as pd

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.76 Safari/537.36'} # This is chrome, you can set whatever browser you like
url="https://www.radarbox24.com/search/flights?origin=LFLL&minarrs=1582675200&maxarrs=1582761599&first=300&reverse=0"
response = requests.get(url, headers=headers)
data_depart=response.json()
df_depart = pd.DataFrame(data_depart) 
variabletodrop=['replay','isFuture', 'departureRelative','statusLabel','arrivalRelative']
df_depart.drop(variabletodrop,axis=1)
df_depart.to_csv('depart2.csv',index=False)
# Out:
#             fid                                           acd     acr   act  \
# 0    1393726871                              Boeing 777-31HER  A6-EPF  B77W
# 1    1393763835                               Airbus A320-214  VQ-BEH  A320
# 2    1393758528                         Airbus A300B4-622R(F)  D-AEAA  A306
# 3    1393828067  Bombardier CL-600-2E25 Regional Jet CRJ-1000  EC-LPN  CRJX
# 4    1393828469                               Airbus A321-212  F-GTAU  A321
# ..          ...                                           ...     ...   ...
# 134  1394072425                               Airbus A320-214  F-HBNI  A320
# 135  1394072961                               Airbus A320-214  OE-IJF  A320
# 136  1394067418   Canadair CL-600-2D24 Regional Jet CRJ-900LR  D-ACNV  CRJ9
# 137  1394083555                               Airbus A320-214  OE-IJU  A320
# 138  1393132868                                Boeing 737-300    None  B733
#
# ...

# %%
import json
import requests
import time
import pandas as pd
import csv
from hdfs import Client
from datetime import datetime
import pandas as pd
from datetime import datetime, timedelta
from threading import Timer
import time
#client_hdfs = Client('http://' + "192.168.122.206"+ ':50070')

x=datetime.today()
y = x.replace(day=x.day, hour=1, minute=0, second=0, microsecond=0) + timedelta(days=1)
delta_t=y-x

secs=delta_t.total_seconds()
date1=str(datetime.now().strftime("%Y-%m-%d"))
datex= datetime.today()
#while(True):     
datex= datetime.today()    
datey=datex - timedelta(days=1)
timestampmax= time.mktime(datex.timetuple())
timestampmin= time.mktime(datey.timetuple())

print(timestampmax,timestampmin)

#headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.76 Safari/537.36'} 
#url="https://www.radarbox24.com/search/flights?destination=LFLL&minarrs="+str(timestampmin)+"&maxarrs="+str(timestampmax)+"&first=20000&reverse=0"
#response = requests.get(url, headers=headers)
#data_arrive=response.json()
#df_arrive = pd.DataFrame(data_arrive) 
#client_hdfs = Client('http://' + "192.168.122.206"+ ':50070')
date1=str(datetime.now().strftime("%Y-%m-%d"))
#with client_hdfs.write('/data/vol/arriveebis/'+datex.strftime("%Y-%m-%d")+'.csv') as writer:
#df_arrive.to_csv(writer, encoding = 'utf-8',index=False)
    
#time.sleep(86400)
# Out:
# 1594297014.0 1594210614.0

# %%
datetime.fromtimestamp(timestampmax+86400).strftime('%c')
# Out:
# 'Fri Jul 10 12:16:54 2020'

# %%
import pandas as pd
import numpy as np
import math
import findspark
import os
import pyspark
from pyspark.sql import SparkSession
from pyspark import SparkContext

from handyspark import *

spark = SparkSession \
    .builder \
    .appName("Pysparkexample") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()

# %%
#data acquistion_2 a spearer par la suite  
#landing_flight_data
#df_load = spark.read.csv('data/df_arrivee.csv',header='true')

df_load = spark.read.csv(('hdfs://192.168.122.206:8020/data/vol/arriveebis/*.csv'),header='true')

#print(df_load.count())
#df_load=df_load.filter("status=='landed' and arreu is not null").dropDuplicates(['arrsu','fnia'])
#print(df_load.count())

# %%
aeroports_ic={}
for i in df_aeroport.collect():
    print(i['aporgci'])
    aeroports_ic[i['aporgci']]=i['aporgic']
# Out:
# Munich
# Geneva
# Figari Sud-Corse
# Lille/Lesquin
# Oslo
# Moscow
# Amman
# Antalya
# Istanbul
# Metz / Nancy
# Alava
# Paris
# St. Petersburg
# Brussels
# Agadir
# Heraklion
# Monastir
# Copenhagen
# Dublin
# Madrid
# Girona
# Luxor
# Dubai
# Beirut
# Tozeur
# Annabah
# Hoogeveen
# Milan
# Lanzarote Island
# Bergamo
# Athens
# None
# Frankfurt
# Cotonou
# Caen/Carpiquet
# Constantine
# Bastia/Poretta
# Berlin
# Ajaccio/Napoléon Bonaparte
# Essaouira
# Batna
# Sétif
# Porto
# Béjaïa
# Prague
# Brussels
# Poitiers/Biard
# Paris
# Tel Aviv
# Liège
# Mykonos Island
# Birmingham
# Verdun
# Lisbon
# Valenciennes/Denain
# Calvi/Sainte-Catherine
# Nice
# Tangier
# Zurich
# Tenerife
# Pau/Pyrénées (Uzein)
# Bodrum
# Tunis
# Nápoli
# Budapest
# Firenze
# Sevilla
# Casablanca
# Kraków
# Leipzig
# Wroclaw
# Algiers
# Alicante
# Manchester
# Djerba
# Las Palmas
# Biarritz/Anglet/Bayonne
# Tlemcen
# Oran
# Belfast
# Izmir
# Salzburg
# Binningen
# Marrakech
# Lyon/Bron
# Mahe Island
# Bristol
# ...

# %%
aeroports_ic
# Out:
# {'Munich': 'EDDM',
#  'Geneva': 'LSGG',
#  'Figari Sud-Corse': 'LFKF',
#  'Lille/Lesquin': 'LFQQ',
#  'Oslo': 'ENGM',
#  'Moscow': 'UUEE',
#  'Amman': 'OJAI',
#  'Antalya': 'LTAI',
#  'Istanbul': 'LTFJ',
#  'Metz / Nancy': 'LFJL',
#  'Alava': 'LEVT',
#  'Paris': 'LFPB',
#  'St. Petersburg': 'ULLI',
#  'Brussels': 'EBBR',
#  'Agadir': 'GMAD',
#  'Heraklion': 'LGIR',
#  'Monastir': 'DTMB',
#  'Copenhagen': 'EKCH',
#  'Dublin': 'EIDW',
#  'Madrid': 'LEMD',
#  'Girona': 'LEGE',
#  'Luxor': 'HELX',
#  'Dubai': 'OMDB',
#  'Beirut': 'OLBA',
#  'Tozeur': 'DTTZ',
#  'Annabah': 'DABB',
#  'Hoogeveen': 'EHHO',
#  'Milan': 'LIMC',
#  'Lanzarote Island': 'GCRR',
#  'Bergamo': 'LIME',
#  'Athens': 'LGAV',
#  None: None,
#  'Frankfurt': 'EDDF',
#  'Cotonou': 'DBBB',
#  'Caen/Carpiquet': 'LFRK',
#  'Constantine': 'DABC',
#  'Bastia/Poretta': 'LFKB',
#  'Berlin': 'EDDB',
#  'Ajaccio/Napoléon Bonaparte': 'LFKJ',
#  'Essaouira': 'GMMI',
#  'Batna': 'DABT',
#  'Sétif': 'DAAS',
#  'Porto': 'LPPR',
# ...

# %%
aerport_ic={'Munich': 'EDDM',
 'Geneva': 'LSGG',
 'Figari Sud-Corse': 'LFKF',
 'Lille/Lesquin': 'LFQQ',
 'Oslo': 'ENGM',
 'Moscow': 'UUEE',
 'Amman': 'OJAI',
 'Antalya': 'LTAI',
 'Istanbul': 'LTFJ',
 'Metz / Nancy': 'LFJL',
 'Alava': 'LEVT',
 'Paris': 'LFPB',
 'St. Petersburg': 'ULLI',
 'Brussels': 'EBBR',
 'Agadir': 'GMAD',
 'Heraklion': 'LGIR',
 'Monastir': 'DTMB',
 'Copenhagen': 'EKCH',
 'Dublin': 'EIDW',
 'Madrid': 'LEMD',
 'Girona': 'LEGE',
 'Luxor': 'HELX',
 'Dubai': 'OMDB',
 'Beirut': 'OLBA',
 'Tozeur': 'DTTZ',
 'Annabah': 'DABB',
 'Hoogeveen': 'EHHO',
 'Milan': 'LIMC',
 'Lanzarote Island': 'GCRR',
 'Bergamo': 'LIME',
 'Athens': 'LGAV',
 'Frankfurt': 'EDDF',
 'Cotonou': 'DBBB',
 'Caen/Carpiquet': 'LFRK',
 'Constantine': 'DABC',
 'Bastia/Poretta': 'LFKB',
 'Berlin': 'EDDB',
 'Ajaccio/Napoléon Bonaparte': 'LFKJ',
 'Essaouira': 'GMMI',
 'Batna': 'DABT',
 'Sétif': 'DAAS',
 'Porto': 'LPPR',
 'Béjaïa': 'DAAE',
 'Prague': 'LKPR',
 'Poitiers/Biard': 'LFBI',
 'Tel Aviv': 'LLBG',
 'Liège': 'EBLG',
 'Mykonos Island': 'LGMK',
 'Birmingham': 'EGBB',
 'Verdun': 'LFHJ',
 'Lisbon': 'LPPT',
 'Valenciennes/Denain': 'LFAV',
 'Calvi/Sainte-Catherine': 'LFKC',
 'Nice': 'LFMN',
 'Tangier': 'GMTT',
 'Zurich': 'LSZH',
 'Tenerife': 'GCTS',
 'Pau/Pyrénées (Uzein)': 'LFBP',
 'Bodrum': 'LTFE',
 'Tunis': 'DTTA',
 'Nápoli': 'LIRN',
 'Budapest': 'LHBP',
 'Firenze': 'LIRQ',
 'Sevilla': 'LEZL',
 'Casablanca': 'GMMN',
 'Kraków': 'EPKK',
 'Leipzig': 'EDDP',
 'Wroclaw': 'EPWR',
 'Algiers': 'DAAG',
 'Alicante': 'LEAL',
 'Manchester': 'EGCC',
 'Djerba': 'DTTJ',
 'Las Palmas': 'GCLP',
 'Biarritz/Anglet/Bayonne': 'LFBZ',
 'Tlemcen': 'DAON',
 'Oran': 'DAOO',
 'Belfast': 'EGAA',
 'Izmir': 'LTBJ',
 'Salzburg': 'LOWS',
 'Binningen': 'EDSI',
 'Marrakech': 'GMMX',
 'Lyon/Bron': 'LFLY',
 'Mahe Island': 'FSIA',
 'Bristol': 'EGGD',
 'London': 'EGSS',
 'Valence/Chabeuil': 'LFLU',
 'Ajaccio': 'LFKY',
 'Bordeaux/Mérignac': 'LFBD',
 'Toulouse': 'LFBO',
 'Bratislava': 'LZIB',
 'Bucharest': 'LROP',
 'Toussus-le-Noble': 'LFPN',
 'Gothenburg': 'ESGG',
 'Lyon': 'LFLL',
 'Catania': 'LICC',
 'Pamiers/Les Pujols': 'LFDJ',
 'Ivalo': 'EFIV',
 'Cluj-Napoca': 'LRCL',
 'Stuttgart': 'EDDS',
 'Venezia': 'LIPZ',
 'Rome': 'LIRF',
 'Fes': 'GMFF',
 'Pontivy': 'LFEG',
 'Barcelona': 'LEBL',
 'Málaga': 'LEMG',
 'Biskra': 'DAUB',
 'Newcastle': 'EGNT',
 'Strasbourg': 'LFST',
 'Amsterdam': 'EHAM',
 'Brest/Guipavas': 'LFRB',
 'Pontoise': 'LFPT',
 'La Roche-sur-Yon/Les Ajoncs': 'LFRI',
 'Zagreb': 'LDZA',
 'Faro': 'LPFR',
 'Nantes': 'LFRS',
 'Montréal': 'CYUL',
 'Düsseldorf': 'EDDL',
 'Fuerteventura Island': 'GCFV',
 'Hurghada': 'HEGN',
 'Muret/Lherm': 'LFBR',
 'Luqa': 'LMML',
 'Palma De Mallorca': 'LEPA',
 'Hamburg': 'EDDH',
 'Warsaw': 'EPWA',
 'Yerevan': 'UDYZ',
 'Edinburgh': 'EGPH',
 'Split': 'LDSP',
 'Cologne': 'EDDK',
 'Bologna': 'LIPE',
 'Rennes/Saint-Jacques': 'LFRN',
 'Vienna': 'LOWW',
 'Farnborough': 'EGLF',
 'Helmbrechts': 'EDQO',
 'Marseille': 'LFML',
 'Lorient/Lann/Bihoué': 'LFRH',
 'Limoges/Bellegarde': 'LFBL'}

# %%
import json
import requests
import time
import pandas as pd
import csv
from hdfs import Client
from datetime import datetime
import pandas as pd
from datetime import datetime, timedelta
from threading import Timer
import time
client_hdfs = Client('http://' + "192.168.122.206"+ ':50070')


aeroports_ic={'Munich': 'EDDM',
 'Geneva': 'LSGG',
 'Figari Sud-Corse': 'LFKF',
 'Lille_Lesquin': 'LFQQ',
 'Oslo': 'ENGM',
 'Moscow': 'UUEE',
 'Amman': 'OJAI',
 'Antalya': 'LTAI',
 'Istanbul': 'LTFJ',
 'Metz_Nancy': 'LFJL',
 'Alava': 'LEVT',
 'Paris': 'LFPB',
 'St. Petersburg': 'ULLI',
 'Brussels': 'EBBR',
 'Agadir': 'GMAD',
 'Heraklion': 'LGIR',
 'Monastir': 'DTMB',
 'Copenhagen': 'EKCH',
 'Dublin': 'EIDW',
 'Madrid': 'LEMD',
 'Girona': 'LEGE',
 'Luxor': 'HELX',
 'Dubai': 'OMDB',
 'Beirut': 'OLBA',
 'Tozeur': 'DTTZ',
 'Annabah': 'DABB',
 'Hoogeveen': 'EHHO',
 'Milan': 'LIMC',
 'Lanzarote Island': 'GCRR',
 'Bergamo': 'LIME',
 'Athens': 'LGAV',
 'Frankfurt': 'EDDF',
 'Cotonou': 'DBBB',
 'Caen_Carpiquet': 'LFRK',
 'Constantine': 'DABC',
 'Bastia_Poretta': 'LFKB',
 'Berlin': 'EDDB',
 'Ajaccio_Napoléon Bonaparte': 'LFKJ',
 'Essaouira': 'GMMI',
 'Batna': 'DABT',
 'Sétif': 'DAAS',
 'Porto': 'LPPR',
 'Béjaïa': 'DAAE',
 'Prague': 'LKPR',
 'Poitiers_Biard': 'LFBI',
 'Tel Aviv': 'LLBG',
 'Liège': 'EBLG',
 'Mykonos Island': 'LGMK',
 'Birmingham': 'EGBB',
 'Verdun': 'LFHJ',
 'Lisbon': 'LPPT',
 'Valenciennes/Denain': 'LFAV',
 'Calvi_Sainte-Catherine': 'LFKC',
 'Nice': 'LFMN',
 'Tangier': 'GMTT',
 'Zurich': 'LSZH',
 'Tenerife': 'GCTS',
 'Pau_Pyrénées (Uzein)': 'LFBP',
 'Bodrum': 'LTFE',
 'Tunis': 'DTTA',
 'Nápoli': 'LIRN',
 'Budapest': 'LHBP',
 'Firenze': 'LIRQ',
 'Sevilla': 'LEZL',
 'Casablanca': 'GMMN',
 'Kraków': 'EPKK',
 'Leipzig': 'EDDP',
 'Wroclaw': 'EPWR',
 'Algiers': 'DAAG',
 'Alicante': 'LEAL',
 'Manchester': 'EGCC',
 'Djerba': 'DTTJ',
 'Las Palmas': 'GCLP',
 'Biarritz_Anglet_Bayonne': 'LFBZ',
 'Tlemcen': 'DAON',
 'Oran': 'DAOO',
 'Belfast': 'EGAA',
 'Izmir': 'LTBJ',
 'Salzburg': 'LOWS',
 'Binningen': 'EDSI',
 'Marrakech': 'GMMX',
 'Lyon/Bron': 'LFLY',
 'Mahe Island': 'FSIA',
 'Bristol': 'EGGD',
 'London': 'EGSS',
 'Valence_Chabeuil': 'LFLU',
 'Ajaccio': 'LFKY',
 'Bordeaux_Mérignac': 'LFBD',
 'Toulouse': 'LFBO',
 'Bratislava': 'LZIB',
 'Bucharest': 'LROP',
 'Toussus-le-Noble': 'LFPN',
 'Gothenburg': 'ESGG',
 'Lyon': 'LFLL',
 'Catania': 'LICC',
 'Pamiers_Les Pujols': 'LFDJ',
 'Ivalo': 'EFIV',
 'Cluj-Napoca': 'LRCL',
 'Stuttgart': 'EDDS',
 'Venezia': 'LIPZ',
 'Rome': 'LIRF',
 'Fes': 'GMFF',
 'Pontivy': 'LFEG',
 'Barcelona': 'LEBL',
 'Málaga': 'LEMG',
 'Biskra': 'DAUB',
 'Newcastle': 'EGNT',
 'Strasbourg': 'LFST',
 'Amsterdam': 'EHAM',
 'Brest_Guipavas': 'LFRB',
 'Pontoise': 'LFPT',
 'La Roche-sur-Yon/Les Ajoncs': 'LFRI',
 'Zagreb': 'LDZA',
 'Faro': 'LPFR',
 'Nantes': 'LFRS',
 'Montréal': 'CYUL',
 'Düsseldorf': 'EDDL',
 'Fuerteventura Island': 'GCFV',
 'Hurghada': 'HEGN',
 'Muret_Lherm': 'LFBR',
 'Luqa': 'LMML',
 'Palma De Mallorca': 'LEPA',
 'Hamburg': 'EDDH',
 'Warsaw': 'EPWA',
 'Yerevan': 'UDYZ',
 'Edinburgh': 'EGPH',
 'Split': 'LDSP',
 'Cologne': 'EDDK',
 'Bologna': 'LIPE',
 'Rennes_Saint-Jacques': 'LFRN',
 'Vienna': 'LOWW',
 'Farnborough': 'EGLF',
 'Helmbrechts': 'EDQO',
 'Marseille': 'LFML',
 'Lorient_Lann_Bihoué': 'LFRH',
 'Limoges_Bellegarde': 'LFBL'}


while(True):     
    datex= datetime.today()    
    datey=datex - timedelta(days=1)
    timestampmax= time.mktime(datex.timetuple())
    timestampmin= time.mktime(datey.timetuple())

    print(timestampmax,timestampmin)
    for aerop in aeroports_ic:
            headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.76 Safari/537.36'} 
            url="https://www.radarbox24.com/search/flights?destination="+str(aeroports_ic[aerop])+"&minarrs="+str(timestampmin)+"&maxarrs="+str(timestampmax)+"&first=20000&reverse=0"
            response = requests.get(url, headers=headers)
            data_arrive=response.json()
            df_arrive = pd.DataFrame(data_arrive) 
            client_hdfs = Client('http://' + "192.168.122.206"+ ':50070')
            with client_hdfs.write('/data/vol/arriveebis/aeroports/'+aerop+'_'+datex.strftime("%Y-%m-%d")+'.csv') as writer:
                df_arrive.to_csv(writer, encoding = 'utf-8',index=False)
    time.sleep(86400)
# Out:
# 1594301661.0 1594215261.0
# https://www.radarbox24.com/search/flights?destination=EDDM&minarrs=1594215261.0&maxarrs=1594301661.0&first=20000&reverse=0
# /data/vol/arriveebis/Munich2020-07-09.csv
# /n
# https://www.radarbox24.com/search/flights?destination=LSGG&minarrs=1594215261.0&maxarrs=1594301661.0&first=20000&reverse=0
# /data/vol/arriveebis/Geneva2020-07-09.csv
# /n
# https://www.radarbox24.com/search/flights?destination=LFKF&minarrs=1594215261.0&maxarrs=1594301661.0&first=20000&reverse=0
# /data/vol/arriveebis/Figari Sud-Corse2020-07-09.csv
# /n
# https://www.radarbox24.com/search/flights?destination=LFQQ&minarrs=1594215261.0&maxarrs=1594301661.0&first=20000&reverse=0
# /data/vol/arriveebis/Lille/Lesquin2020-07-09.csv
# /n
# https://www.radarbox24.com/search/flights?destination=ENGM&minarrs=1594215261.0&maxarrs=1594301661.0&first=20000&reverse=0
# /data/vol/arriveebis/Oslo2020-07-09.csv
# /n
# ...

# %%
df_arrive = pd.DataFrame(data_arrive)

# %%
df_arrive['day']
# Out:
# 0    8 Jul
# 1    8 Jul
# 2    9 Jul
# Name: day, dtype: object

# %%
import json
import requests
import time
import pandas as pd
import csv
from hdfs import Client
from datetime import datetime
import pandas as pd
from datetime import datetime, timedelta
from threading import Timer
import time
client_hdfs = Client('http://' + "192.168.122.206"+ ':50070')


aeroports_ic={'Munich': 'EDDM',
 'Geneva': 'LSGG',
 'Figari Sud-Corse': 'LFKF',
 'Lille_Lesquin': 'LFQQ',
 'Oslo': 'ENGM',
 'Moscow': 'UUEE',
 'Amman': 'OJAI',
 'Antalya': 'LTAI',
 'Istanbul': 'LTFJ',
 'Metz_Nancy': 'LFJL',
 'Alava': 'LEVT',
 'Paris': 'LFPB',
 'St. Petersburg': 'ULLI',
 'Brussels': 'EBBR',
 'Agadir': 'GMAD',
 'Heraklion': 'LGIR',
 'Monastir': 'DTMB',
 'Copenhagen': 'EKCH',
 'Dublin': 'EIDW',
 'Madrid': 'LEMD',
 'Girona': 'LEGE',
 'Luxor': 'HELX',
 'Dubai': 'OMDB',
 'Beirut': 'OLBA',
 'Tozeur': 'DTTZ',
 'Annabah': 'DABB',
 'Hoogeveen': 'EHHO',
 'Milan': 'LIMC',
 'Lanzarote Island': 'GCRR',
 'Bergamo': 'LIME',
 'Athens': 'LGAV',
 'Frankfurt': 'EDDF',
 'Cotonou': 'DBBB',
 'Caen_Carpiquet': 'LFRK',
 'Constantine': 'DABC',
 'Bastia_Poretta': 'LFKB',
 'Berlin': 'EDDB',
 'Ajaccio_Napoléon Bonaparte': 'LFKJ',
 'Essaouira': 'GMMI',
 'Batna': 'DABT',
 'Sétif': 'DAAS',
 'Porto': 'LPPR',
 'Béjaïa': 'DAAE',
 'Prague': 'LKPR',
 'Poitiers_Biard': 'LFBI',
 'Tel Aviv': 'LLBG',
 'Liège': 'EBLG',
 'Mykonos Island': 'LGMK',
 'Birmingham': 'EGBB',
 'Verdun': 'LFHJ',
 'Lisbon': 'LPPT',
 'Valenciennes/Denain': 'LFAV',
 'Calvi_Sainte-Catherine': 'LFKC',
 'Nice': 'LFMN',
 'Tangier': 'GMTT',
 'Zurich': 'LSZH',
 'Tenerife': 'GCTS',
 'Pau_Pyrénées (Uzein)': 'LFBP',
 'Bodrum': 'LTFE',
 'Tunis': 'DTTA',
 'Nápoli': 'LIRN',
 'Budapest': 'LHBP',
 'Firenze': 'LIRQ',
 'Sevilla': 'LEZL',
 'Casablanca': 'GMMN',
 'Kraków': 'EPKK',
 'Leipzig': 'EDDP',
 'Wroclaw': 'EPWR',
 'Algiers': 'DAAG',
 'Alicante': 'LEAL',
 'Manchester': 'EGCC',
 'Djerba': 'DTTJ',
 'Las Palmas': 'GCLP',
 'Biarritz_Anglet_Bayonne': 'LFBZ',
 'Tlemcen': 'DAON',
 'Oran': 'DAOO',
 'Belfast': 'EGAA',
 'Izmir': 'LTBJ',
 'Salzburg': 'LOWS',
 'Binningen': 'EDSI',
 'Marrakech': 'GMMX',
 'Lyon/Bron': 'LFLY',
 'Mahe Island': 'FSIA',
 'Bristol': 'EGGD',
 'London': 'EGSS',
 'Valence_Chabeuil': 'LFLU',
 'Ajaccio': 'LFKY',
 'Bordeaux_Mérignac': 'LFBD',
 'Toulouse': 'LFBO',
 'Bratislava': 'LZIB',
 'Bucharest': 'LROP',
 'Toussus-le-Noble': 'LFPN',
 'Gothenburg': 'ESGG',
 'Lyon': 'LFLL',
 'Catania': 'LICC',
 'Pamiers_Les Pujols': 'LFDJ',
 'Ivalo': 'EFIV',
 'Cluj-Napoca': 'LRCL',
 'Stuttgart': 'EDDS',
 'Venezia': 'LIPZ',
 'Rome': 'LIRF',
 'Fes': 'GMFF',
 'Pontivy': 'LFEG',
 'Barcelona': 'LEBL',
 'Málaga': 'LEMG',
 'Biskra': 'DAUB',
 'Newcastle': 'EGNT',
 'Strasbourg': 'LFST',
 'Amsterdam': 'EHAM',
 'Brest_Guipavas': 'LFRB',
 'Pontoise': 'LFPT',
 'La Roche-sur-Yon/Les Ajoncs': 'LFRI',
 'Zagreb': 'LDZA',
 'Faro': 'LPFR',
 'Nantes': 'LFRS',
 'Montréal': 'CYUL',
 'Düsseldorf': 'EDDL',
 'Fuerteventura Island': 'GCFV',
 'Hurghada': 'HEGN',
 'Muret_Lherm': 'LFBR',
 'Luqa': 'LMML',
 'Palma De Mallorca': 'LEPA',
 'Hamburg': 'EDDH',
 'Warsaw': 'EPWA',
 'Yerevan': 'UDYZ',
 'Edinburgh': 'EGPH',
 'Split': 'LDSP',
 'Cologne': 'EDDK',
 'Bologna': 'LIPE',
 'Rennes_Saint-Jacques': 'LFRN',
 'Vienna': 'LOWW',
 'Farnborough': 'EGLF',
 'Helmbrechts': 'EDQO',
 'Marseille': 'LFML',
 'Lorient_Lann_Bihoué': 'LFRH',
 'Limoges_Bellegarde': 'LFBL'}


while(True):     
    datex= datetime.today()    
    datey=datex - timedelta(days=1)
    timestampmax= time.mktime(datex.timetuple())
    timestampmin= time.mktime(datey.timetuple())

    print(timestampmax,timestampmin)
    for aerop in aeroports_ic:
            headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.76 Safari/537.36'} 
            url="https://www.radarbox24.com/search/flights?origin="+str(aeroports_ic[aerop])+"&minarrs="+str(timestampmin)+"&maxarrs="+str(timestampmax)+"&first=20000&reverse=0"
            response = requests.get(url, headers=headers)
            data_depart=response.json()
            df_depart = pd.DataFrame(data_depart) 
            print(df_arrive)
            client_hdfs = Client('http://' + "192.168.122.206"+ ':50070')
            with client_hdfs.write('/data/vol/departbis/aeroports/'+aerop+'_'+datex.strftime("%Y-%m-%d")+'.csv') as writer:
              #  df_depart.to_csv(writer, encoding = 'utf-8',index=False)
    time.sleep(86400)
# Out:
# 1594303693.0 1594217293.0
#           fid   acd     acr   act  alic              alna    alt  \
# 0  1431837623  None  F-HIFR  P28A  None              None   3200
# 1  1431846695  None  F-GPYM  AT45   CLG  Chalair Aviation  14875
# 2  1432123957  None  EI-DHE  B738   RYR           Ryanair   3050
#
#               apdstci apdstco apdstia  ... arrau   arrs         arrsu depau  \
# 0  Limoges/Bellegarde  France     LIG  ...   NaN    NaN           NaN   NaN
# 1  Limoges/Bellegarde  France     LIG  ...   NaN    NaN           NaN   NaN
# 2  Limoges/Bellegarde  France     LIG  ...   NaN  11:45  1.594288e+09   NaN
#
#     deps         depsu   arre         arreu  delay depdelay
# 0    NaN           NaN    NaN           NaN    NaN      NaN
# 1    NaN           NaN    NaN           NaN    NaN      NaN
# 2  09:00  1.594282e+09  12:19  1.594290e+09  797.0   2067.0
#
# [3 rows x 93 columns]
#           fid   acd     acr   act  alic              alna    alt  \
# ...
