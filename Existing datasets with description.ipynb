# %% [markdown]
# Label description of merged_data:
# * aircraft_aircrafttype_iatacode: aircraft type designator defined by the International Air Transport Association (IATA)
# * aircraft_aircrafttype_icaocode: aircraft type designator defined by the International Civil Aviation Organization
# * aircraft_aircrafttype_modelname
# * airlines_airline_iatacode: airlines type designator defined by the IATA
# * airlines_airline_icaocode: airlines type designator defined by the ICAO
# * airlines_airline_name
# * airlines_operator_iatacode: airlines operator type designator defined by the IATA
# * airlines_operator_icaocode: airlines operator type designator defined by the ICAO
# * airlines_operator_name
# * airportresources_boarding_departurelounge
# * airportresources_boarding_gates
# * airportresources_checkin_checkinarea
# * airportresources_checkin_desks
# * airportresources_terminal
# * airports_destination_iatacode
# * airports_destination_icaocode
# * airports_destination_name
# * airports_next_iatacode
# * airports_next_icaocode
# * airports_next_name
# * countrytype_code
# * countrytype_description
# * flightnumbers_callsign
# * flightnumbers_iataflightnumber
# * flightnumbers_icaoflightnumber
# * flightnumbers_internalflightnumber
# * flightnumbers_operatoriataflightnumber
# * flightnumbers_operatoricaoflightnumber
# * flightnumbers_operatorinternalflightnumber
# * flightnumbers_operatorsuffix
# * flightnumbers_operatortripnumber
# * flightnumbers_suffix
# * flightnumbers_tripnumber
# * flightstatus_code: number of status codes to denote the state of the flight
# * flightstatus_description
# * gid
# * last_update_fme
# * publiccomment
# * remark_code
# * remark_description
# * servicetype_description
# * servicetype_iatacode
# * timestamps_cancellationdate
# * timestamps_eobt
# * timestamps_sobt
# * turnflightinternalid
# * numero
# * pression
# * direction_de_vent
# * vitesse_de_vent
# * temperature
# * humidité
# * visibilité
# * nebulosite
# * hauteur_neige
# * precipitations_1
# * precipitations_3
# * nom
# * longitude
# * latitude
# * day
# * month
# * year
# * hour
# * minute
# * delay
#
# The difference between an airline and the operator is the following:
# * An airline is an Air Transport Enterprise offering or operating an international scheduled air service
# * An operator is an airline that offers non-scheduled air transport services.

# %% [markdown]
# Label description of covid_19_data(1):
# * SNo
# * ObservationDate
# * Province/State
# * Country/Region
# * Last Update
# * Confirmed
# * Deaths
# * Recovered

# %% [markdown]
# Label description of Air-Algérie_reviews, Air_Arabia_reviews, airfrance_reviews, easyjet_reviews, Eurowings_reviews, Lufthansa_reviews, ryanair_reviews, royal_air_maroc_reviews, transavia_reviews, turkishairlines_reviews, Vueling-Airlines_reviews:
# * titre
# * avis
# * nbetoile
# * mois
# * annee
# * depart
# * destination
# trajet

# %% [markdown]
# Label description of airlinesreviews_total_infos, outF:
# * airline
# * meanstars: score over 5
# * negatif_reviews_prct: percentage of negative reviews
# * positf_reviews_prct: percentage of positive reviews

# %% [markdown]
# Label description of arrive27:
# * fid: flight id
# * acd: aircraft model name
# * acr:
# * act: aircraft type
# * alic: aircraft icia
# * alna: airport name
# * alt: altitude
# * apdstci: city
# * apdstco: counrty
# * apdstia: airport departure iata code
# * apdstic: airport departure icao code
# * apdstla: airport departure latitude
# * apdstlo: airport departure longitude
# * apdstst: airport departure state
# * apdsttz
# * apdsttznl
# * apdsttzns
# * aporgci: airport destination city
# * aporgco: airport destination country
# * aporgia: airport destination iata
# * aporgic: airport destination icao
# * aporgla: airport destination latitude
# * aporglo: airport destination longitude
# * aporgst: airport destination state
# * aporgtz
# * aporgtznl
# * aporgtzns
# * arrau
# * arre
# * arreu
# * arrs
# * arrsu
# * cancel: flight canceled or not
# * cs
# * depau
# * depe: delay departure
# * depeu
# * deps
# * depsu
# * fnia: flight next iata code
# * fnic: flight next icao codd
# * mrgarru
# * mrgdepu
# * ms
# * so
# * svd
# * lastlalot: next latitude and longitude
# * departure
# * departure_meta
# * arrival
# * arrival_meta
# * status
# * delay
# * progress
# * duration
# * durationType
# * distance
# * departureRelative
# * arrivalRelative
# * statusLabel
# * depsts
# * depc
# * arrsts
# * arrc
# * day
# * depdate
# * arrdate
# * replay
# * isFuture
# * pcnt
# * tkotc
# * lngtc
# * deptaxi
# * arrdelay
# * depdelay
# * arrtaxi

# %% [markdown]
# Label description of covid19data:
# * caseslabel
# * timestamp
# * pays

# %% [markdown]
# Label description of meteoX:
# * numero
# * pression
# * direction_de_vent
# * vitesse_de_vent
# * temperature
# * humidité
# * visibilité
# * nebulosite
# * hauteur_neige
# * precipitations_1
# * precipitations_3
# * nom
# * longitude
# * latitude
# * timestamp
# * timestamp_30_before
# * timestamp_30_after

# %% [markdown]
# Label description of donnees-synop-essentielles-omm:
# * ID OMM station
# * Date
# * Pression au niveau mer
# * Variation de pression en 3 heures
# * Type de tendance barométrique
# * Direction du vent moyen 10 mn
# * Vitesse du vent moyen 10 mn* Température
# * Point de rosée
# * Humidité
# * Visibilité horizontale
# * Temps présent
# * Temps passé 1
# * Temps passé 2
# * Nebulosité totale
# * Nébulosité  des nuages de l' étage inférieur
# * Hauteur de la base des nuages de l'étage inférieur
# * Type des nuages de l'étage inférieur
# * Type des nuages de l'étage moyen
# * Type des nuages de l'étage supérieur
# * Pression station
# * Niveau barométrique
# * Géopotentiel
# * Variation de pression en 24 heures
# * Température minimale sur 12 heures
# * Température minimale sur 24 heures
# * Température maximale sur 12 heures
# * Température maximale sur 24 heures
# * Température minimale du sol sur 12 heures
# * Méthode de mesure Température du thermomètre mouillé
# * Température du thermomètre mouillé
# * Rafale sur les 10 dernières minutes
# * Rafales sur une période
# * Periode de mesure de la rafale
# * Etat du sol
# * Hauteur totale de la couche de neige, glace, autre au sol
# * Hauteur de la neige fraîche
# * Periode de mesure de la neige fraiche
# * Précipitations dans la dernière heure
# * Précipitations dans les 3 dernières heures
# * Précipitations dans les 6 dernières heures
# * Précipitations dans les 12 dernières heures
# * Précipitations dans les 24 dernières heures
# * Phénomène spécial 1
# * Phénomène spécial 2
# * Phénomène spécial 3
# * Phénomène spécial 4
# * Nébulosité couche nuageuse 1
# * Type nuage 1
# * Hauteur de base 1
# * Nébulosité couche nuageuse 2
# * Type nuage 2
# * Hauteur de base 2
# * Nébulosité couche nuageuse 3
# * Type nuage 3
# * Hauteur de base 3
# * Nébulosité couche nuageuse 4
# * Type nuage 4
# * Hauteur de base 4
# * Coordonnees
# * Nom
# * Type de tendance barométrique
# * Temps passé 1
# * Temps présent
# * Température (°C)
# * Température minimale sur 12 heures (°C)
# * Température minimale sur 24 heures (°C)
# * Température maximale sur 12 heures (°C)
# * Température maximale sur 24 heures (°C)
# * Température minimale du sol sur 12 heures (en °C)
# * Altitude
# * Longitude
# * Latitude
# * communes (name)
# * communes (code)
# * EPCI (name): Etablissement public de coopération intercommunale
# * EPCI (code)
# * department (name)
# * department (code)
# * region (name)
# * region (code)
# * mois_de_l_annee

# %% [markdown]
# Label description of flightslandingatlyon:
# * airlines_airline_name
# * airportresources_terminal
# * remark_description
# * timestamps_atot_outstation
# * timestamps_sibt
# * aircraft_aircrafttype_icaocode
# * airportresources_unboarding_gates
# * remark_code
# * flightnumbers_icaoflightnumber
# * airports_origin_icaocode
# * airports_previous_name
# * countrytype_code
# * flightnumbers_operatortripnumber
# * airports_previous_icaocode
# * flightstatus_code
# * gid
# * countrytype_description
# * flightnumbers_suffix
# * flightnumbers_internalflightnumber
# * airports_origin_name
# * airportresources_baggagedelivery_carrousels
# * turnflightinternalid
# * timestamps_eldt
# * timestamps_aldt
# * flightnumbers_operatoriataflightnumber
# * timestamps_diversiondate
# * flightnumbers_tripnumber
# * timestamps_modificationdate
# * airlines_airline_icaocode
# * flightnumbers_operatoricaoflightnumber
# * servicetype_description
# * flightnumbers_callsign
# * timestamps_eibt
# * last_update_fme
# * flightnumbers_operatorinternalflightnumber
# * servicetype_iatacode
# * flightnumbers_operatorsuffix
# * airlines_operator_iatacode
# * flightstatus_description
# * aircraft_aircrafttype_iatacode
# * airportresources_unboarding_airbridges
# * airports_origin_iatacode
# * airlines_operator_name
# * publiccomment
# * timestamps_aibt
# * airlines_airline_iatacode
# * airports_previous_iatacode
# * airlines_operator_icaocode
# * aircraft_aircrafttype_modelname
# * airportresources_baggagedelivery_arrivallounge
# * flightnumbers_iataflightnumber
# * timestamps_cancellationdate
# * airportresources_baggagedelivery_baggagebelts
# * airportresources_runway
# * retard_terissage
# * retard_arrive_pstat

# %% [markdown]
# Label description of flightlandingatlyonfinal:
# * aircraft_aircrafttype_iatacode
# * aircraft_aircrafttype_icaocode
# * aircraft_aircrafttype_modelname
# * airlines_airline_iatacode
# * airlines_airline_icaocode
# * airlines_airline_name
# * airlines_operator_iatacode
# * airlines_operator_icaocode
# * airlines_operator_name
# * airportresources_baggagedelivery_arrivallounge
# * airportresources_baggagedelivery_baggagebelts
# * airportresources_baggagedelivery_carrousels
# * airportresources_runway
# * airportresources_terminal
# * airportresources_unboarding_airbridges
# * airportresources_unboarding_gates
# * airports_origin_iatacode
# * airports_origin_icaocode
# * airports_origin_name
# * airports_previous_iatacode
# * airports_previous_icaocode
# * airports_previous_name
# * countrytype_code
# * countrytype_description
# * flightnumbers_callsign
# * flightnumbers_iataflightnumber
# * flightnumbers_icaoflightnumber
# * flightnumbers_internalflightnumber
# * flightnumbers_operatoriataflightnumber
# * flightnumbers_operatoricaoflightnumber
# * flightnumbers_operatorinternalflightnumber
# * flightnumbers_operatorsuffix
# * flightnumbers_operatortripnumber
# * flightnumbers_suffix
# * flightnumbers_tripnumber
# * flightstatus_code
# * flightstatus_description
# * gid,last_update_fme
# * publiccomment,remark_code
# * remark_description
# * servicetype_description
# * servicetype_iatacode
# * timestamps_aibt
# * timestamps_aldt
# * timestamps_atot_outstation
# * timestamps_cancellationdate
# * timestamps_diversiondate
# * timestamps_eibt
# * timestamps_eldt
# * timestamps_modificationdate
# * timestamps_sibt
# * turnflightinternalid
# * retard_pt_stat
# * retard_teriss

# %% [markdown]
# Label description of joined:
# * _c0
# * aircraft_aircrafttype_iatacode
# * aircraft_aircrafttype_icaocode
# * aircraft_aircrafttype_modelname
# * airlines_airline_iatacode
# * airlines_airline_icaocode
# * airlines_airline_name
# * airlines_operator_iatacode
# * airlines_operator_icaocode
# * airlines_operator_name
# * airportresources_boarding_departurelounge
# * airportresources_boarding_gates
# * airportresources_checkin_checkinarea
# * airportresources_checkin_desks
# * airportresources_terminal
# * airports_destination_iatacode
# * airports_destination_icaocode
# * airports_destination_name
# * airports_next_iatacode
# * airports_next_icaocode
# * airports_next_name
# * countrytype_code
# * countrytype_description
# * flightnumbers_callsign
# * flightnumbers_iataflightnumber
# * flightnumbers_icaoflightnumber
# * flightnumbers_internalflightnumber
# * flightnumbers_operatoriataflightnumber
# * flightnumbers_operatoricaoflightnumber
# * flightnumbers_operatorinternalflightnumber
# * flightnumbers_operatorsuffix
# * flightnumbers_operatortripnumber
# * flightnumbers_suffix
# * flightnumbers_tripnumber
# * flightstatus_code
# * flightstatus_description
# * gid
# * last_update_fme
# * publiccomment
# * remark_code
# * remark_description
# * servicetype_description
# * servicetype_iatacode
# * timestamps_aobt
# * timestamps_atot
# * timestamps_cancellationdate
# * timestamps_eobt
# * timestamps_modificationdate
# * timestamps_sobt
# * turnflightinternalid
# * numero
# * pression
# * direction_de_vent
# * vitesse_de_vent
# * temperature
# * humidité
# * visibilité
# * nebulosite
# * hauteur_neige
# * precipitations_1
# * precipitations_3
# * nom,longitude
# * latitude
# * timestamp
# * timestamp_30_before
# * timestamp_30_after
# * day
# * month
# * year
# * hour
# * minute
# * delay

# %% [markdown]
# Label description of MeteoHistoClean:
# * numer_sta
# * date
# * pmer
# * dd
# * ff
# * t
# * u
# * vv
# * n
# * ht_neige
# * rr1
# * rr3
# * nom
# * timestamp
# * latitude
# * longitude

# %% [markdown]
# Label Description of newapi:
# * fid: flight id
# * acd: aircraft model name
# * acr
# * act: aircraft type
# * alic: aircraft icia
# * alna: aircraft name
# * alt: altitude
# * apdstci: airport departure city
# * apdstco: airport departure counrty
# * apdstia: airport departure iata code
# * apdstic: airport departure icao code
# * apdstla: airport departure latitude
# * apdstlo: airport departure longitude
# * apdstst: airport departure state
# * apdsttz
# * apdsttznl
# * apdsttzns
# * aporgci: airport destination city
# * aporgco: airport destination country
# * aporgia: airport destination iata
# * aporgic: airport destination icao
# * aporgla: airport destination latitude
# * aporglo: airport destination longitude
# * aporgst: airport destination state
# * aporgtz
# * aporgtznl
# * aporgtzns
# * arrau
# * arre
# * arreu
# * arrs
# * arrsu
# * cancel: flight canceled or not
# * cs
# * depau
# * depe
# * depeu
# * deps
# * depsu
# * fnia
# * fnic
# * mrgarru
# * mrgdepu
# * so
# * svd
# * lastlalot
# * departure
# * departure_meta
# * arrival
# * arrival_meta
# * status
# * delay
# * progress
# * duration
# * durationType
# * distance
# * departureRelative
# * arrivalRelative
# * statusLabel
# * depsts
# * depc
# * arrsts
# * arrc
# * day
# * depdate
# * arrdate
# * replay
# * isFuture
# * pcnt
# * tkotc
# * lngtc
# * deptaxi
# * arrdelay
# * depdelay
# * arrtaxi

# %% [markdown]
# Label description of testdata:
# * airlines_airline_name
# * airports_previous_name
# * flightnumbers_internalflightnumber
# * retard_pt_stat
# * retard_teriss
# * weekday
# * year
# * month
# * hour

# %% [markdown]
# Label Description of time_series_19_confirmed:
# * Province/State
# * Country/Region
# * Lat
# * Long
# * 1/22/20
# * 1/23/20
# * 1/24/20
# * 1/25/20
# * 1/26/20
# * 1/27/20
# * 1/28/20
# * 1/29/20
# * 1/30/20
# * 1/31/20
# * 2/1/20
# * 2/2/20
# * 2/3/20
# * 2/4/20
# * 2/5/20
# * 2/6/20
# * 2/7/20
# * 2/8/20
# * 2/9/20
# * 2/10/20
# * 2/11/20
# * 2/12/20
# * 2/13/20
# * 2/14/20
# * 2/15/20
# * 2/16/20
# * 2/17/20
# * 2/18/20
# * 2/19/20
# * 2/20/20
# * 2/21/20
# * 2/22/20
# * 2/23/20
# * 2/24/20
# * 2/25/20
# * 2/26/20
# * 2/27/20
# * 2/28/20
# * 2/29/20
# * 3/1/20
# * 3/2/20
# * 3/3/20
# * 3/4/20
# * 3/5/20
# * 3/6/20
# * 3/7/20
# * 3/8/20
# * 3/9/20
# * 3/10/20
# * 3/11/20
# * 3/12/20
# * 3/13/20
# * 3/14/20
# * 3/15/20
# * 3/16/20
# * 3/17/20
# * 3/18/20
# * 3/19/20
# * 3/20/20
# * 3/21/20
# * 3/22/20
# * 3/23/20
# * 3/24/20
# * 3/25/20
# * 3/26/20
# * 3/27/20
# * 3/28/20
# * 3/29/20
# * 3/30/20

# %% [markdown]
# Label description of volX:
# * _c0
# * aircraft_aircrafttype_iatacode
# * aircraft_aircrafttype_icaocode
# * aircraft_aircrafttype_modelname
# * airlines_airline_iatacode
# * airlines_airline_icaocode
# * airlines_airline_name
# * airlines_operator_iatacode
# * airlines_operator_icaocode
# * airlines_operator_name
# * airportresources_boarding_departurelounge
# * airportresources_boarding_gates
# * airportresources_checkin_checkinarea
# * airportresources_checkin_desks
# * airportresources_terminal
# * airports_destination_iatacode
# * airports_destination_icaocode
# * airports_destination_name
# * airports_next_iatacode
# * airports_next_icaocode
# * airports_next_name
# * countrytype_code
# * countrytype_description
# * flightnumbers_callsign
# * flightnumbers_iataflightnumber
# * flightnumbers_icaoflightnumber
# * flightnumbers_internalflightnumber
# * flightnumbers_operatoriataflightnumber
# * flightnumbers_operatoricaoflightnumber
# * flightnumbers_operatorinternalflightnumber
# * flightnumbers_operatorsuffix
# * flightnumbers_operatortripnumber
# * flightnumbers_suffix
# * flightnumbers_tripnumber
# * flightstatus_code
# * flightstatus_description
# * gid
# * last_update_fme
# * publiccomment
# * remark_code
# * remark_description
# * servicetype_description
# * servicetype_iatacode
# * timestamps_aobt
# * timestamps_atot
# * timestamps_cancellationdate
# * timestamps_eobt
# * timestamps_modificationdate
# * timestamps_sobt
# * turnflightinternalid
